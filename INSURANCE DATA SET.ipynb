# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('/content/insurance_claims.csv')

# %%
data.head
# Out:
# <bound method NDFrame.head of      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       2014-10-17           OH
# 1                   228   42         342868       2006-06-27           IN
# 2                   134   29         687698       2000-09-06           OH
# 3                   256   41         227811       1990-05-25           IL
# 4                   228   44         367455       2014-06-06           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       1991-07-16           OH
# 996                 285   41         186934       2014-01-05           IL
# 997                 130   34         918516       2003-02-17           OH
# 998                 458   62         533940       2011-11-18           IL
# 999                 456   60         556080       1996-11-11           OH
#
# ...

# %%
data.tail
# Out:
# <bound method NDFrame.tail of      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       2014-10-17           OH
# 1                   228   42         342868       2006-06-27           IN
# 2                   134   29         687698       2000-09-06           OH
# 3                   256   41         227811       1990-05-25           IL
# 4                   228   44         367455       2014-06-06           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       1991-07-16           OH
# 996                 285   41         186934       2014-01-05           IL
# 997                 130   34         918516       2003-02-17           OH
# 998                 458   62         533940       2011-11-18           IL
# 999                 456   60         556080       1996-11-11           OH
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %%
data.describe()
# Out:
#        months_as_customer          age  policy_number  policy_deductable  \
# count         1000.000000  1000.000000    1000.000000        1000.000000
# mean           203.954000    38.948000  546238.648000        1136.000000
# std            115.113174     9.140287  257063.005276         611.864673
# min              0.000000    19.000000  100804.000000         500.000000
# 25%            115.750000    32.000000  335980.250000         500.000000
# 50%            199.500000    38.000000  533135.000000        1000.000000
# 75%            276.250000    44.000000  759099.750000        2000.000000
# max            479.000000    64.000000  999435.000000        2000.000000
#
#        policy_annual_premium  umbrella_limit    insured_zip  capital-gains  \
# count            1000.000000    1.000000e+03    1000.000000    1000.000000
# mean             1256.406150    1.101000e+06  501214.488000   25126.100000
# std               244.167395    2.297407e+06   71701.610941   27872.187708
# ...

# %%
(data.describe().T)
# Out:
#                               count          mean           std         min  \
# months_as_customer           1000.0  2.039540e+02  1.151132e+02        0.00
# age                          1000.0  3.894800e+01  9.140287e+00       19.00
# policy_number                1000.0  5.462386e+05  2.570630e+05   100804.00
# policy_deductable            1000.0  1.136000e+03  6.118647e+02      500.00
# policy_annual_premium        1000.0  1.256406e+03  2.441674e+02      433.33
# umbrella_limit               1000.0  1.101000e+06  2.297407e+06 -1000000.00
# insured_zip                  1000.0  5.012145e+05  7.170161e+04   430104.00
# capital-gains                1000.0  2.512610e+04  2.787219e+04        0.00
# capital-loss                 1000.0 -2.679370e+04  2.810410e+04  -111100.00
# incident_hour_of_the_day     1000.0  1.164400e+01  6.951373e+00        0.00
# number_of_vehicles_involved  1000.0  1.839000e+00  1.018880e+00        1.00
# ...

# %%
data.shape
# Out:
# (1000, 40)

# %%
data.isnull()
# Out:
#      months_as_customer    age  policy_number  policy_bind_date  policy_state  \
# 0                 False  False          False             False         False
# 1                 False  False          False             False         False
# 2                 False  False          False             False         False
# 3                 False  False          False             False         False
# 4                 False  False          False             False         False
# ..                  ...    ...            ...               ...           ...
# 995               False  False          False             False         False
# 996               False  False          False             False         False
# 997               False  False          False             False         False
# 998               False  False          False             False         False
# 999               False  False          False             False         False
#
# ...

# %%
data.drop('_c39',axis=1,inplace=True)

# %%
cate = []
for i in data.columns:
  if(data[i].dtypes == "object"):
    cate.append(i)
    print(i)
# Out:
# policy_bind_date
# policy_state
# policy_csl
# insured_sex
# insured_education_level
# insured_occupation
# insured_hobbies
# insured_relationship
# incident_date
# incident_type
# collision_type
# incident_severity
# authorities_contacted
# incident_state
# incident_city
# incident_location
# property_damage
# police_report_available
# auto_make
# auto_model
# fraud_reported

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lbl_encode = LabelEncoder()
for i in cate:
  data[i]=data[[i]].apply(lbl_encode.fit_transform)

# %%
data.rename(columns={'policy_bind_date':'DATE'})
# Out:
#      months_as_customer  age  policy_number  DATE  policy_state  policy_csl  \
# 0                   328   48         521585   940             2           1
# 1                   228   42         342868   635             1           1
# 2                   134   29         687698   413             2           0
# 3                   256   41         227811    19             0           1
# 4                   228   44         367455   922             0           2
# ..                  ...  ...            ...   ...           ...         ...
# 995                   3   38         941851    67             2           2
# 996                 285   41         186934   907             0           0
# 997                 130   34         918516   514             2           1
# 998                 458   62         533940   831             0           2
# 999                 456   60         556080   283             2           1
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = data['vehicle_claim']
plt.plot(x)
plt.xlabel('vechicle_claim')
plt.title('INSURANCE REPORT')
# Out:
# Text(0.5, 1.0, 'INSURANCE REPORT')

# %%
x = data['vehicle_claim']
y = data['age']
plt.bar(x,y)
plt.xlabel('vehicle_claim')
plt.ylabel('age')
plt.title('INSURANCE REPORT')
# Out:
# Text(0.5, 1.0, 'INSURANCE REPORT')

# %%
x = data['age']
y = data['policy_deductable']
plt.scatter(x,y)
plt.xlabel('age')
plt.ylabel('policy_deductable')
plt.title('INSURANCE REPORT')
# Out:
# Text(0.5, 1.0, 'INSURANCE REPORT')

# %%
x = data['vehicle_claim'][0:30]
plt.pie(x)
plt.xlabel('vehicle_claim')
plt.title('INSURANCE REPORT')
# Out:
# Text(0.5, 1.0, 'INSURANCE REPORT')

# %%
x = data['policy_deductable']
plt.hist(x)
plt.xlabel('policy_deductable')
plt.title('INSURANCE REPORT')
# Out:
# Text(0.5, 1.0, 'INSURANCE REPORT')

# %%
x = data['policy_deductable'][0:50]
sns.lineplot(x)
# Out:
# <Axes: ylabel='policy_deductable'>

# %%
x = data['policy_deductable']
sns.countplot(x)
# Out:
# <Axes: ylabel='count'>

# %%
sns.barplot(x=data['age'],y=data['injury_claim'])
# Out:
# <Axes: xlabel='age', ylabel='injury_claim'>

# %%
sns.scatterplot(x=data['policy_deductable'],y=data['age'])
# Out:
# <Axes: xlabel='policy_deductable', ylabel='age'>

# %%
x = data['policy_deductable']
sns.distplot(x)
# Out:
# <ipython-input-104-ec21e612b627>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x)
# <Axes: xlabel='policy_deductable', ylabel='Density'>

# %%
x = data['age']
sns.boxplot(x)
# Out:
# <Axes: >

# %%
x = data.drop('fraud_reported', axis=1)
print(x)
# Out:
#      months_as_customer  age  policy_number  policy_bind_date  policy_state  \
# 0                   328   48         521585               940             2
# 1                   228   42         342868               635             1
# 2                   134   29         687698               413             2
# 3                   256   41         227811                19             0
# 4                   228   44         367455               922             0
# ..                  ...  ...            ...               ...           ...
# 995                   3   38         941851                67             2
# 996                 285   41         186934               907             0
# 997                 130   34         918516               514             2
# 998                 458   62         533940               831             0
# 999                 456   60         556080               283             2
#
# ...

# %%
y = data['fraud_reported']
print(y)
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 995    0
# 996    0
# 997    0
# 998    0
# 999    0
# Name: fraud_reported, Length: 1000, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.5,random_state=0)

# %%
from sklearn.preprocessing  import StandardScaler

# %%
a = StandardScaler()

# %%
x_train = a.fit_transform(x_train)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier()
clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_predict = clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_predict,y_test)
# Out:
# 0.802

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_predict,y_test)
# Out:
# array([[332,  55],
#        [ 44,  69]])

# %%
from sklearn.tree import export_graphviz
import graphviz

# %%
graphviz.Source(export_graphviz(clf,feature_names = x.columns, filled = True))
